# %%
#Library to choose any random words from the list of words.
import random 

#To say good luck to the player.
Name = input("Hello player can you tell me your name so I can wish you luck *+*? ") 
# Here the user is asked to enter the name first 

print("Good Luck ! ",Name) 

words = ['rainbow', 'computer', 'science', 'programming','python', 'mathematics',
         'player', 'condition', 'reverse', 'water', 'board', 'geeks'] 

# Below Function will choose one random word from the list of words 
word = random.choice(words) 
print("--------------**!Let's set and go!**----------------")
print("Guess the characters") 

Guesses = '' 

# any number of turns can be used here 
num = input("Please enter a chance you want:")
Turns = int(num)

while Turns > 0: 

# The counts wrong guessed numbers
    failed = 0

# All characters from the input and word taking one at a time.
 
    for char in word: 

#Comparing that character with the character in guesses by player
        if char in Guesses: 
            print(char) 
        else: 
            print("*") 

#For every failure 1 will be incremented in failure 
        failed += 1


    if failed == 0: 
#User will win the game if failure is 0 and 'You Win' will be given as output 
        print("You Won!") 
#Below code will print the correct word 
        print("The word is: ", word) 
        break

#If user has input the wrong alphabet then, it will ask player to enter another alphabet.
    guess = input("Guess a character:") 

#Every input character will be stored in guesses 
    Guesses += guess 

#Checks input with the character in word 
    if guess not in word: 
        Turns -= 1

#If the character doesn’t match the word then “Wrong” will be given as output 
    print("Wrong character guessed") 

#This will print the number of turns left for the player
    print("You have", + Turns, 'more guesses') 

    if Turns == 0: 
        print("You Loose") 
        
    def play():
        try_again = input("Would you like to try again?[y/n]")
        return try_again.lower() == 'y'
    
#This is how a guess game is created and oreover we can create a different similar games with similar logic.
# Out:
# Hello player can you tell me your name so I can wish you luck *+*? Priya
# Good Luck !  Priya
# --------------**!Let's set and go!**----------------
# Guess the characters
# Please enter a chance you want:5
# *
# *
# *
# *
# *
# Guess a character:g
# Wrong character guessed
# You have 5 more guesses
# g
# *
# *
# *
# *
# Guess a character:k
# Wrong character guessed
# You have 5 more guesses
# g
# *
# *
# k
# *
# Guess a character:s
# Wrong character guessed
# You have 5 more guesses
# g
# *
# *
# k
# s
# Guess a character:t
# Wrong character guessed
# You have 4 more guesses
# g
# *
# *
# k
# s
# Guess a character:s
# Wrong character guessed
# You have 4 more guesses
# g
# *
# *
# k
# s
# Guess a character:l
# Wrong character guessed
# You have 3 more guesses
# g
# *
# *
# k
# s
# Guess a character:m
# Wrong character guessed
# You have 2 more guesses
# g
# *
# *
# k
# s
# Guess a character:q
# Wrong character guessed
# You have 1 more guesses
# g
# *
# *
# k
# s
# ...
